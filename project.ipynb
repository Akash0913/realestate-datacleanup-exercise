# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset, and it was downloaded using web scraping techniques. The data contains registers from **Fotocasa** which is one of the most popular real estate websites in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro, and in no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd

# This CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
max_value = ds['price'].max()

# Find the row where the price is the maximum
most_expensive_house = ds[ds['price'] == max_value]

# Extract the address and price
address = most_expensive_house['address'].values[0]
price = most_expensive_house['price'].values[0]

# Print the address and price
print(f"The house with adress {address} is the most expensive and its price is {price} USD.")
# Out:
# The house with adress El Escorial is the most expensive and its price is 8500000 USD.

# %% [markdown]
# #### Exercise 02. Which is the cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
min_value = ds['price'].min()
cheapest_house = ds[ds['price'] == min_value]
address = cheapest_house['address'].values[0]
price = cheapest_house['price'].values[0]
print(f"The house with address {address} is the cheapest and its price is {price} USD.")
# Out:
# The house with address Parla is the cheapest and its price is 0 USD.

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The biggest house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smallest house is located on County Road 1 N and its surface is 200 meters`

# %%
max_surface = ds['surface'].max()
min_surface = ds['surface'].min()
biggest_house = ds[ds['surface'] == max_surface]
smallest_house = ds[ds['surface'] == min_surface]
biggest_house_address = biggest_house['address'].values[0]
biggest_house_surface = biggest_house['surface'].values[0]
smallest_house_address = smallest_house['address'].values[0]
smallest_house_surface = smallest_house['surface'].values[0]
print(f"The biggest house is located on {biggest_house_address} and its surface is {biggest_house_surface} meters.")
print(f"The smallest house is located on {smallest_house_address} and its surface is {smallest_house_surface} meters.")
# Out:
# The biggest house is located on Sevilla la Nueva and its surface is 249000.0 meters.
# The smallest house is located on Calle Amparo,  Madrid Capital and its surface is 15.0 meters.

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the names of the populations with a comma as a separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
ds['realEstate_name'] = ds['realEstate_name'].astype(str).fillna('')
real_estate_names = ds['realEstate_name'].tolist()
names_string = ", ".join(real_estate_names)
print(names_string)
# Out:
# ferrari 57 inmobiliaria, tecnocasa fuenlabrada ferrocarril, look find boadilla, tecnocasa fuenlabrada ferrocarril, ferrari 57 inmobiliaria, expimad, expimad, expimad, expimad, modesta, inmobiliaria nuevo leganes, gm house, alia consulting inmobiliario sl, alia consulting inmobiliario sl, tecnocasa navalcarnero, mejocasa, mejocasa, fisol, fisol, oih, mario, matibo, isabel, isidro paris molano, ruben, david perez, myriam curiel, jorge, particular, engels volkers sanchinarro, jaime valcarce consulting inmobiliario, jaime valcarce consulting inmobiliario, inmobiliaria reylank propiedades, inmobiliaria reylank propiedades, inmobiliaria reylank propiedades, altter, spi real estate, spi real estate, nozar sa, vivienda2, vivantial, vivienda2, vivantial, vivienda2, vivienda2, ingescasa, vivienda2, nurin, vivienda2, vivienda2, vivienda2, vivantial, vivienda2, vivienda2, vivienda2, vivienda2, egido real estate, vivienda2, zona madrid, vivienda2, vivienda2, nozar sa, vivienda2, vivienda2, vivien
# ...

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`True` or `False`) followed by the rows/cols that contains NAs.

# %%
ds = pd.read_csv('assets/real_estate.csv', sep=';')
has_missing_values = ds.isnull().values.any()
print(f"Contains missing values: {has_missing_values}")
if has_missing_values:
    print("\nRows and columns with missing values:")
    missing_info = ds[ds.isnull().any(axis=1)]
    print(missing_info)
else:
    print("No missing values found.")
# Out:
# Contains missing values: True
#
# Rows and columns with missing values:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# ...

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions.

# %%
original_shape = ds.shape
ds_cleaned = ds.dropna()
cleaned_shape = ds_cleaned.shape
print(f"Original DataFrame dimensions: {original_shape}")
print(f"Dimensions after removing rows with NA values: {cleaned_shape}")
# Out:
# Original DataFrame dimensions: (15335, 38)
# Dimensions after removing rows with NA values: (0, 38)

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value.

# %%
arroyomolinos_df = ds[ds['level5'] == 'Arroyomolinos (Madrid)']
mean_price_arroyomolinos = arroyomolinos_df['price'].mean()
print(f"The mean price of properties in Arroyomolinos (Madrid) is {mean_price_arroyomolinos} USD.")
# Out:
# The mean price of properties in Arroyomolinos (Madrid) is 294541.59854014596 USD.

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
arroyomolinos_df = ds[ds['level5'].str.contains('Arroyomolinos', case=False, na=False)]
arroyomolinos_df = arroyomolinos_df.dropna(subset=['price'])
plt.figure(figsize=(10, 6))
plt.hist(arroyomolinos_df['price'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of Property Prices in Arroyomolinos (Madrid)')
plt.xlabel('Price (USD)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# The historgram shows a right skew with the majority of the pricing being around the center of 28000 USD approximately.

# %% [markdown]
# #### Exercise 09. Are the average prices of "Valdemorillo" and "Galapagar" the same? (★★☆)
#
# Print both average prices and then write a conclusion about them.

# %%
data_v = ds[ds['level5'] == "Valdemorillo"]
data_g = ds[ds['level5'] == "Galapagar"]
mean_price_v = data_v['price'].mean()
mean_price_g = data_g['price'].mean()
print(f"Conclusion:  The average price of Valdemorillo is {mean_price_v} and the average price of Galapagar is {mean_price_g}.  So in conclusion, the values are not the same.")
# Out:
# Conclusion:  The average price of Valdemorillo is 363860.2931034483 and the average price of Galapagar is 360063.20238095237.  So in conclusion, the values are not the same.

# %% [markdown]
# #### Exercise 10. Are the average prices per square meter (price/m2) of "Valdemorillo" and "Galapagar" the same? (★★☆)
#
# Print both average prices and then write a conclusion about it.
#
# Hint: Create a new column called `pps` (price per square meter) and then analyze the values.

# %%
ds['pps'] = ds['price'] / ds['surface']
valdemorillo_df = ds[ds['level5'].str.contains('Valdemorillo', case=False, na=False)]
galapagar_df = ds[ds['level5'].str.contains('Galapagar', case=False, na=False)]
valdemorillo_df = valdemorillo_df.dropna(subset=['pps'])
galapagar_df = galapagar_df.dropna(subset=['pps'])
mean_pps_valdemorillo = valdemorillo_df['pps'].mean()
mean_pps_galapagar = galapagar_df['pps'].mean()
print(f"The mean price per square meter in Valdemorillo is {mean_pps_valdemorillo:.2f} USD/m².")
print(f"The mean price per square meter in Galapagar is {mean_pps_galapagar:.2f} USD/m².")
if mean_pps_valdemorillo == mean_pps_galapagar:
    print("The average price per square meter in Valdemorillo and Galapagar is the same.")
else:
    print("The average price per square meter in Valdemorillo and Galapagar is different.")
# Out:
# The mean price per square meter in Valdemorillo is 1317.95 USD/m².
# The mean price per square meter in Galapagar is 1606.32 USD/m².
# The average price per square meter in Valdemorillo and Galapagar is different.

# %% [markdown]
# #### Exercise 11. Analyze the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot`, then write a conclusion about it.

# %%
ds_cleaned = ds.dropna(subset=['price', 'surface'])
plt.figure(figsize=(10, 6))
plt.scatter(ds_cleaned['surface'], ds_cleaned['price'], color='blue', alpha=0.5)
plt.title('Scatter Plot: Surface Area vs Price of Houses')
plt.xlabel('Surface Area (m²)')
plt.ylabel('Price (USD)')
plt.grid(True)
plt.show()

# %% [markdown]
# The scatterplot shows the majority of the data being vertically formed at the y axis which means I should change my scale to better represent the data. It appears there is not much variation in the surface area of the houses but lots of variation in their pricing.

# %% [markdown]
# #### Exercise 12. How many real estate agencies does the dataset contain? (★★☆)
#
# Print the obtained value.

# %%
if 'realEstate_name' in ds.columns:
    unique_agencies = ds['realEstate_name'].nunique()
    print(f"The dataset contains {unique_agencies} unique real estate agencies.")
else:
    print("The column for real estate agencies was not found.")
# Out:
# The dataset contains 1821 unique real estate agencies.

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses.

# %%
if 'level5' in ds.columns:
    population_counts = ds['level5'].value_counts()
    most_houses_population = population_counts.idxmax()
    most_houses_count = population_counts.max()
    print(f"The population with the most houses is {most_houses_population} with {most_houses_count} houses.")
else:
    print("The 'level5' column was not found.")
# Out:
# The population with the most houses is  Madrid Capital with 6643 houses.

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of Madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`.

# %%
south_belt_populations = ["Fuenlabrada", "Leganes", "Getafe", "Alcorcon"]
south_belt_df = ds[ds['level5'].isin(south_belt_populations)]
print(south_belt_df.head())
print(f"The South Belt subset contains {len(south_belt_df)} entries.")
# Out:
#      Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 1             2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 3             4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 161         162       153440116  False                          prolucisa
# 169         170       153920011  False                       grupo tizona
# 214         215       153950663  False                       bidx1 espana
#
#      phone_realEstate                                       url_inmueble  \
# 1         916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3         916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 161       916350416.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 169       911226046.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 214       914892974.0  https://www.fotocasa.es/es/comprar/vivienda/fu...
#
#      rooms  bathrooms  surface   price  ... level4Id level5Id level6Id  \
# ...

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in Exercise 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
ds = pd.read_csv('assets/real_estate.csv', sep=';')

# Create the subset for the South Belt of Madrid
south_belt_populations = ["Fuenlabrada", "Leganes", "Getafe", "Alcorcon"]
south_belt_df = ds[ds['level5'].isin(south_belt_populations)]

# Calculate the median prices for each population
median_prices = south_belt_df.groupby('level5')['price'].median()

# Plot the bar chart of median prices
median_prices.plot(kind='bar', color='skyblue', edgecolor='black', figsize=(10, 6))
plt.title('Median Prices by Population in the South Belt of Madrid')
plt.xlabel('Population')
plt.ylabel('Median Price (USD)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# Getafe has a higher median of prices in the South Belt of Madrid by a margin of over 10,000 USD.

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in Exercise 14) (★★★)
#
# Print both values for each variable.

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
south_belt_populations = ["Fuenlabrada", "Leganes", "Getafe", "Alcorcon"]
south_belt_df = ds[ds['level5'].isin(south_belt_populations)]
mean_values = south_belt_df[['price', 'rooms', 'surface', 'bathrooms']].mean()
variance_values = south_belt_df[['price', 'rooms', 'surface', 'bathrooms']].var()
print("Sample Mean:\n", mean_values)
print("\nSample Variance:\n", variance_values)
# Out:
# Sample Mean:
#  price        225906.087954
# rooms             3.095969
# surface         116.429224
# bathrooms         1.679537
# dtype: float64
#
# Sample Variance:
#  price        1.561600e+10
# rooms        5.907722e-01
# surface      4.350850e+03
# bathrooms    5.663503e-01
# dtype: float64

# %% [markdown]
# #### Exercise 17. What is the most expensive house in each population? You must use the subset obtained in Exercise 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population.

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
south_belt_populations = ["Fuenlabrada", "Leganes", "Getafe", "Alcorcon"]
south_belt_df = ds[ds['level5'].isin(south_belt_populations)]
most_expensive_houses = south_belt_df.loc[south_belt_df.groupby('level5')['price'].idxmax()]
print(most_expensive_houses[['level5', 'price', 'rooms', 'surface', 'bathrooms']])
# Out:
#             level5    price  rooms  surface  bathrooms
# 11561  Fuenlabrada   490000    4.0    274.0        3.0
# 2881        Getafe  1050000    6.0    600.0        4.0

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in Exercise 14) (★★★)
#
# For the normalization method, you can use the one you consider; there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot.
#
# Hint: You can help yourself by reviewing the *multihist* demo of Matplotlib.

# %%
import matplotlib.pyplot as plt
south_belt_df['normalized_price'] = south_belt_df.groupby('level5')['price'].transform(lambda x: (x - x.mean()) / x.std())
plt.figure(figsize=(10, 6))
for population in south_belt_populations:
    subset = south_belt_df[south_belt_df['level5'] == population]
    plt.hist(subset['normalized_price'], bins=20, alpha=0.5, label=population)
plt.title('Normalized Price Distributions by Population in the South Belt of Madrid')
plt.xlabel('Normalized Price')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_556/2743900072.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_belt_df['normalized_price'] = south_belt_df.groupby('level5')['price'].transform(lambda x: (x - x.mean()) / x.std())

# %% [markdown]
# The plot of 4 histograms shows a right skew with a high of about 68 frequency.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in Exercise 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square meter) and then analyze the values.

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
south_belt_populations = ["Fuenlabrada", "Leganes", "Getafe", "Alcorcon"]
south_belt_df = ds[ds['level5'].isin(south_belt_populations)].copy()
south_belt_df.loc[:, 'pps'] = south_belt_df['price'] / south_belt_df['surface']
getafe_df = south_belt_df[south_belt_df['level5'] == 'Getafe']
alcorcon_df = south_belt_df[south_belt_df['level5'] == 'Alcorcon']
print(f"Number of valid entries for Alcorcon: {len(alcorcon_df)}")
print("Alcorcon Data (with Price and Surface):")
print(alcorcon_df[['price', 'surface', 'pps']].dropna())
mean_pps_getafe = getafe_df['pps'].mean()
mean_pps_alcorcon = alcorcon_df['pps'].mean()
print(f"The mean price per square meter in Getafe is {mean_pps_getafe:.2f} USD/m².")
print(f"The mean price per square meter in Alcorcon is {mean_pps_alcorcon:.2f} USD/m².")
# Out:
# Number of valid entries for Alcorcon: 0
# Alcorcon Data (with Price and Surface):
# Empty DataFrame
# Columns: [price, surface, pps]
# Index: []
# The mean price per square meter in Getafe is 2066.31 USD/m².
# The mean price per square meter in Alcorcon is nan USD/m².

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph. You must use the subset obtained in Exercise 14 (★★☆)
#
# Hint: Make a scatter plot of each population using subplots.

# %%
import pandas as pd
import matplotlib.pyplot as plt
ds = pd.read_csv('assets/real_estate.csv', sep=';')
south_belt_populations = ["Fuenlabrada", "Leganes", "Getafe", "Alcorcon"]
south_belt_df = ds[ds['level5'].isin(south_belt_populations)].copy()
south_belt_df = south_belt_df.dropna(subset=['price', 'surface'])
south_belt_df['pps'] = south_belt_df['price'] / south_belt_df['surface']
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
for i, population in enumerate(south_belt_populations):
    subset = south_belt_df[south_belt_df['level5'] == population]
    ax = axes[i // 2, i % 2]
    ax.hist(subset['pps'], bins=20, alpha=0.75, edgecolor='black', color='skyblue')
    ax.set_title(f"{population} - Price per Square Meter")
    ax.set_xlabel('Price per Square Meter (USD)')
    ax.set_ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in Exercise 14) (★★★★)
#
# Execute the following cell, and then start coding in the next one. You must implement a simple code that transforms the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
from ipyleaflet import Map, basemaps

# Map centered on (60 degrees latitude and -2.2 degrees longitude)
# Latitude, longitude
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/xyzservices/lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 6
#       1 from ipyleaflet import Map, basemaps
#       3 # Map centered on (60 degrees latitude and -2.2 degrees longitude)
#       4 # Latitude, longitude
#       5 map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20,
# ----> 6     basemap=basemaps.Stamen.Terrain)
#       7 map
#
# File ~/.local/lib/python3.11/site-packages/xyzservices/lib.py:46, in Bunch.__getattr__(self, key)
#      44     return self.__getitem__(key)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/xyzservices/lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 4
#       1 from ipyleaflet import Marker
#       3 # Rename 'map' to 'mymap' to avoid conflicts with the Python built-in 'map'
# ----> 4 mymap = Map(center=(60, -2.2), zoom=2, min_zoom=1, max_zoom=20, basemap=basemaps.Stamen.Terrain)
#       6 # Create a dictionary for population colors
#       7 population_colors = {
#       8     "Fuenlabrada": "blue",
#       9     "Leganes": "green",
#      10     "Getafe": "red",
# ...
